# %%
import numpy as np
import pandas as pd
import math

# %%
def readDataset(file):
    dataset = pd.read_csv(file)

    X = dataset.sample(frac = 1)

    X = np.array(X)

    X = np.append(np.ones((np.shape(X)[0],1)),X,1)
    label = dataset.iloc[:,-1:]

    X_train = np.array(X[:math.floor(len(X)*0.7)])
    X_test = np.array(X[math.floor(len(X)*0.7)+1:])

    print(X_train)
    print(X_test)
    
   
    
    
    return X_train,X_test,X

# %%
def generateParams():
    #Seed
    w0 = np.random.uniform(-1,1,(np.shape(X)[1]-1,1))
    print("Seed \n",w0)
    numOfIterations  = 1000000
    print("Number of Iterations - ",numOfIterations)
    learning_rate = 1
#     print("Shape of Training Set " np.shape(X_train))
    
    return w0,numOfIterations,learning_rate

# %%
def generatePerceptron(w0,numOfIterations,X_train,learning_rate,X):
    for f in range (numOfIterations):
        terminate = True

        misclassified = 0
        count = 0
        for i in X_train :
            count+=1
            x = np.reshape(i[:-1],(1,np.shape(X)[1]-1))

            lab = i[-1]
            if lab == 0:
                lab = -1

            w1 = np.matmul(x,w0)

            if ((lab)*w1 < 0):
                w0 = w0 + learning_rate*(np.transpose(x))*(lab)
                terminate = False
                misclassified+=1
                break
    
        if terminate :
            break
    #         print(w0)

    print("Perceptron :\n" ,w0)

    return w0

# %%
def getAccuracy(w0,X_test,X):
    incorrect = 0
    for i in X_test:
        x = np.reshape(i[:-1],(1,np.shape(X)[1]-1))

        lab = i[-1]
        if lab == 0:
            lab = -1

        w1 = np.matmul(x,w0)
    #         print(w1)
        if ((lab)*w1 < 0):
            incorrect+=1


    print("Misclassified - ",incorrect)
    numRows = np.shape(X_test)[0]
    incorrect/= numRows
    print("Accuracy - ",1-incorrect)
    return

# %%
print("\n \n Dataset 2 \n")
X_train,X_test,X = readDataset('dataset_LP_2.csv')
w0,numberOfIterations,learning_rate = generateParams();
w0 = generatePerceptron(w0,numberOfIterations,X_train,learning_rate,X)
accuracy = getAccuracy(w0,X_test,X)

print("Dataset 1 \n")
X_train,X_test,X = readDataset('dataset_LP_1.txt')
w0,numberOfIterations,learning_rate = generateParams();
w0 = generatePerceptron(w0,numberOfIterations,X_train,learning_rate,X)
accuracy = getAccuracy(w0,X_test,X)
# Out:
#
#  Dataset 2
#
# [[ 1.         -0.74581876  1.21234806  1.31230189  1.        ]
#  [ 1.         -1.78748946 -0.35429925 -1.16286156  0.        ]
#  [ 1.          3.63506535 -1.07430763 -1.07229614  0.        ]
#  ...
#  [ 1.         -2.88218043 -0.92110663 -0.76592413  0.        ]
#  [ 1.         -2.96049257 -1.75416115  0.66866482  1.        ]
#  [ 1.         -1.58575579 -0.95740113 -1.03540591  0.        ]]
# [[ 1.         -2.50078544 -1.75010209 -1.06098799  0.        ]
#  [ 1.         -1.07809662  0.43553601  0.94656266  1.        ]
#  [ 1.         -3.12214442  0.05725857  1.34136456  1.        ]
#  ...
#  [ 1.          0.38712916 -1.78714961 -1.37204267  0.        ]
#  [ 1.         -1.31834631 -0.33647695  1.17732733  1.        ]
#  [ 1.          2.14586999  0.55372652 -1.05887193  0.        ]]
# Seed
#  [[-0.84829703]
#  [ 0.7627361 ]
#  [-0.84490318]
#  [-0.32013205]]
# Number of Iterations -  1000000
# Perceptron :
#  [[ 5.15170297]
#  [-0.70507731]
#  [ 2.72896847]
#  [21.35645822]]
# Misclassified -  0
# Accuracy -  1.0
# Dataset 1
#
# [[ 1.        1.8664    7.7763   -0.23849  -2.9634    0.      ]
#  [ 1.       -6.4247    9.5311    0.022844 -6.8517    1.      ]
#  [ 1.       -0.70346   2.957    -3.5947   -3.1457    1.      ]
#  ...
#  [ 1.        2.0193    0.82356   4.6369    1.4202    0.      ]
#  [ 1.       -2.41      3.7433   -0.40215  -1.2953    1.      ]
#  [ 1.       -1.8219   -6.8824    5.4681    0.057313  1.      ]]
# [[  1.         4.6361    -2.6611     2.8358     1.1991     0.      ]
#  [  1.         3.9433     2.5017     1.5215     0.903      0.      ]
#  [  1.        -1.7713   -10.7665    10.2184    -1.0043     1.      ]
#  ...
#  [  1.        -1.7322    -9.2828     7.719     -1.7168     1.      ]
#  [  1.         1.594      4.7055     1.3758     0.081882   0.      ]
#  [  1.        -2.5919    -1.0553     3.8949     0.77757    1.      ]]
# Seed
#  [[-0.76073029]
#  [-0.27387761]
#  [-0.52917008]
#  [-0.06195379]
#  [ 0.47822439]]
# Number of Iterations -  1000000
# Perceptron :
#  [[ 705.23926971]
#  [-805.7491276 ]
#  [-399.24985008]
#  [-531.53921778]
#  [ -18.30167561]]
# Misclassified -  3
# Accuracy -  0.9927007299270073
