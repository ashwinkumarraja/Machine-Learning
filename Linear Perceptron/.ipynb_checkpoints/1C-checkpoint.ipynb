# %%
import numpy as np
import pandas as pd
import math

# Team :
# Abhinand V Chari - 2017B4A71143H
# Ashwin Kumar Raja - 2017B4A70599H
# Sajith K - 2017B4A71012H


# Problem 1C

# %%
def readDataset(file):
    dataset = pd.read_csv(file)

    X = dataset.sample(frac = 1)

    X = np.array(X)

    X = np.append(np.ones((np.shape(X)[0],1)),X,1)
    label = dataset.iloc[:,-1:]

    X_train = np.array(X[:math.floor(len(X)*0.7)])
    X_test = np.array(X[math.floor(len(X)*0.7)+1:])

    print(X_train)
    print(X_test)
    
   
    
    
    return X_train,X_test,X

# %%
def generateParams():
    #Seed
    w0 = np.random.uniform(-1,1,(np.shape(X)[1]-1,1))
    print("Seed \n",w0)
    numOfIterations  = 1000000
    print("Number of Iterations - ",numOfIterations)
    learning_rate = 1
#     print("Shape of Training Set " np.shape(X_train))
    
    return w0,numOfIterations,learning_rate

# %%
def generatePerceptron(w0,numOfIterations,X_train,learning_rate,X):
    for f in range (numOfIterations):
        terminate = True

        misclassified = 0
        count = 0
        for i in X_train :
            count+=1
            x = np.reshape(i[:-1],(1,np.shape(X)[1]-1))

            lab = i[-1]
            if lab == 0:
                lab = -1

            w1 = np.matmul(x,w0)

            if ((lab)*w1 < 0):
                w0 = w0 + learning_rate*(np.transpose(x))*(lab)
                terminate = False
                misclassified+=1
                break
    
        if terminate :
            break
    #         print(w0)

    print("Perceptron :\n" ,w0)

    return w0

# %%
def getAccuracy(w0,X_test,X):
    incorrect = 0
    for i in X_test:
        x = np.reshape(i[:-1],(1,np.shape(X)[1]-1))

        lab = i[-1]
        if lab == 0:
            lab = -1

        w1 = np.matmul(x,w0)
    #         print(w1)
        if ((lab)*w1 < 0):
            incorrect+=1


    print("Misclassified - ",incorrect)
    numRows = np.shape(X_test)[0]
    incorrect/= numRows
    print("Accuracy - ",1-incorrect)
    return

# %%
print("\n \n Dataset 2 \n")
X_train,X_test,X = readDataset('dataset_LP_2.csv')
w0,numberOfIterations,learning_rate = generateParams();
w0 = generatePerceptron(w0,numberOfIterations,X_train,learning_rate,X)
accuracy = getAccuracy(w0,X_test,X)

print("Dataset 1 \n")
X_train,X_test,X = readDataset('dataset_LP_1.txt')
w0,numberOfIterations,learning_rate = generateParams();
w0 = generatePerceptron(w0,numberOfIterations,X_train,learning_rate,X)
accuracy = getAccuracy(w0,X_test,X)
# Out:
#
#  Dataset 2
#
# [[ 1.         -3.10105194 -1.98301914 -1.23633067  0.        ]
#  [ 1.         -2.21389219  0.27370694  0.58244363  1.        ]
#  [ 1.         -1.51401886 -0.61198752  0.35385894  1.        ]
#  ...
#  [ 1.         -1.80230628  0.17252813 -0.99247003  0.        ]
#  [ 1.          4.48068591  0.08264458 -1.25839973  0.        ]
#  [ 1.         -0.35544326  0.67596801 -0.90615643  0.        ]]
# [[ 1.          1.98369858  0.1119683   0.92753618  1.        ]
#  [ 1.          5.72373059  0.16932231  0.70844164  1.        ]
#  [ 1.         -2.6740129   0.84799424  1.04724168  1.        ]
#  ...
#  [ 1.         -1.7273076  -0.26519642  1.26746577  1.        ]
#  [ 1.          1.02133385 -1.86620049  0.74489769  1.        ]
#  [ 1.         -2.09962376  0.72174596 -0.93855223  0.        ]]
# Seed
#  [[0.78883026]
#  [0.21689925]
#  [0.40576347]
#  [0.0815728 ]]
# Number of Iterations -  1000000
# Perceptron :
#  [[ 6.78883026]
#  [-0.78599429]
#  [ 1.40044301]
#  [20.18225561]]
# Misclassified -  0
# Accuracy -  1.0
# Dataset 1
#
# [[ 1.       4.364   -3.1039   2.3757   0.78532  0.     ]
#  [ 1.      -2.4198  -0.24418  0.70146  0.41809  1.     ]
#  [ 1.      -2.902   -7.6563  11.8318  -0.84268  1.     ]
#  ...
#  [ 1.      -1.7101  -8.7903   7.9735  -0.45475  1.     ]
#  [ 1.      -3.8053   2.4273   0.6809  -1.0871   1.     ]
#  [ 1.       1.9321   6.0423   0.26019 -2.053    0.     ]]
# [[ 1.      -3.9204   4.0723  -0.23678 -2.1151   1.     ]
#  [ 1.       0.64295  7.1018   0.3493  -0.41337  0.     ]
#  [ 1.      -2.1059   1.1815  -0.53324 -0.82716  1.     ]
#  ...
#  [ 1.       3.0864  -2.5845   2.2309   0.30947  0.     ]
#  [ 1.       3.2351   9.647   -3.2074  -2.5948   0.     ]
#  [ 1.      -6.9599   8.9931   0.2182  -4.572    1.     ]]
# Seed
#  [[ 0.75220806]
#  [ 0.90256389]
#  [ 0.37654832]
#  [-0.08081107]
#  [-0.9854739 ]]
# Number of Iterations -  1000000
